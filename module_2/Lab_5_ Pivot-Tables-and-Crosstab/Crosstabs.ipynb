# %%
# Import Libraries

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### 1. Import the moovies dataset

# %% [markdown]
# # https://www.kaggle.com/carolzhangdc/imdb-5000-movie-dataset

# %%
movie=pd.read_csv("Desktop\movie_metadata.csv")
movie.head(20)
# Out:
#     color      director_name  num_critic_for_reviews  duration  \
# 0   Color      James Cameron                   723.0     178.0
# 1   Color     Gore Verbinski                   302.0     169.0
# 2   Color         Sam Mendes                   602.0     148.0
# 3   Color  Christopher Nolan                   813.0     164.0
# 4     NaN        Doug Walker                     NaN       NaN
# 5   Color     Andrew Stanton                   462.0     132.0
# 6   Color          Sam Raimi                   392.0     156.0
# 7   Color       Nathan Greno                   324.0     100.0
# 8   Color        Joss Whedon                   635.0     141.0
# 9   Color        David Yates                   375.0     153.0
# 10  Color        Zack Snyder                   673.0     183.0
# 11  Color       Bryan Singer                   434.0     169.0
# 12  Color       Marc Forster                   403.0     106.0
# 13  Color     Gore Verbinski                   313.0     151.0
# ...

# %% [markdown]
# ### 2. Use crosstabs to show the number of moovies per country

# %%
pd.crosstab(movie.director_name, movie.country, margins=True, margins_name='Total')
# Out:
# country             Afghanistan  Argentina  Aruba  Australia  Bahamas  \
# director_name
# A. Raven Cruz                 0          0      0          0        0
# Aaron Hann                    0          0      0          0        0
# Aaron Schneider               0          0      0          0        0
# Aaron Seltzer                 0          0      0          0        0
# Abel Ferrara                  0          0      0          0        0
# ...                         ...        ...    ...        ...      ...
# Álex de la Iglesia            0          0      0          0        0
# Émile Gaudreault              0          0      0          0        0
# Éric Tessier                  0          0      0          0        0
# Étienne Faure                 0          0      0          0        0
# Total                         1          4      1         53        1
#
# country             Belgium  Brazil  Bulgaria  Cambodia  Cameroon  ...  \
# ...

# %%
pd.crosstab(movie.director_name, movie.country)

# %% [markdown]
# ### 3. Create a crosstab to show the number of films per director and genre splitted by country

# %%
pd.crosstab(movie.director_name, movie.country)
# Out:
# country             Afghanistan  Argentina  Aruba  Australia  Bahamas  \
# director_name
# A. Raven Cruz                 0          0      0          0        0
# Aaron Hann                    0          0      0          0        0
# Aaron Schneider               0          0      0          0        0
# Aaron Seltzer                 0          0      0          0        0
# Abel Ferrara                  0          0      0          0        0
# ...                         ...        ...    ...        ...      ...
# Zoran Lisinac                 0          0      0          0        0
# Álex de la Iglesia            0          0      0          0        0
# Émile Gaudreault              0          0      0          0        0
# Éric Tessier                  0          0      0          0        0
# Étienne Faure                 0          0      0          0        0
#
# country             Belgium  Brazil  Bulgaria  Cambodia  Cameroon  ...  Spain  \
# ...

# %% [markdown]
# ### 4. Average duration of filmes grouped by color

# %%
pd.crosstab(movie.duration, movie.color, margins=True, margins_name='Total')
# Out:
# color      Black and White  Color  Total
# duration
# 7.0                      0      2      2
# 11.0                     0      1      1
# 14.0                     0      1      1
# 20.0                     0      1      1
# 22.0                     0      6      6
# ...                    ...    ...    ...
# 325.0                    0      1      1
# 330.0                    0      1      1
# 334.0                    0      1      1
# 511.0                    0      1      1
# Total                  209   4801   5010
#
# [191 rows x 3 columns]

# %% [markdown]
# ### 5. Average number of likes per director (assuming that total film's likes are counted as a sum of actor's likes)

# %%
pd.crosstab(movie.director_facebook_likes, movie.director_name, margins=True, margins_name='Total')
# Out:
# director_name            A. Raven Cruz  Aaron Hann  Aaron Schneider  \
# director_facebook_likes
# 0.0                                  1           1                0
# 2.0                                  0           0                0
# 3.0                                  0           0                0
# 4.0                                  0           0                0
# 5.0                                  0           0                0
# ...                                ...         ...              ...
# 20000.0                              0           0                0
# 21000.0                              0           0                0
# 22000.0                              0           0                0
# 23000.0                              0           0                0
# Total                                1           1                1
#
# director_name            Aaron Seltzer  Abel Ferrara  Adam Brooks  \
# director_facebook_likes
# ...
