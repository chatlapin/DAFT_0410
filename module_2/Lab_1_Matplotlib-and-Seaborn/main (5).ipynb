# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
df=pd.DataFrame()
df['x']=np.arange(0,100)
df['y']=df['x']**2

plt.scatter(x,y)

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2df=pd.DataFrame()
df['x']=np.arange(0,100)
df['y']=df['x']**2

fig, ax=plt.subplots(figsize=(10,6))
ax.scatter(df['x'], df['y'])
plt.xlabel("x")
plt.ylabel("y")

plt.show()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code heredf['x']=np.arange(0,100)
df['y']=df['x']**2

fig, ax=plt.subplots(figsize=(10,6))
ax.scatter(x=df['x'], y=df['y'])
plt.xlabel("x")
plt.ylabel("y")

plt.show()

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt
import math

def forward(x):
    return np.exp(x)

def reverse(x):
    return np.log(x)

# Define a Gaussian probability density function:
mu,std=6.6,0.75
rv = stats.norm(loc=mu,scale=std)

# x sample
x = np.linspace(mu - 3 * std, mu + 3 * std, 100)

# Display
fig, axes = plt.subplots(2, 1)
axes[0].plot(x, rv.pdf(x), color='r')
axes[0].set_title('linear scale')
axes[1].plot(x, rv.pdf(x), color='r')
axes[1].set_title('exponential scale')
axes[1].set_xscale('function', functions=(forward, reverse))
axes[1].set_xlim(x.min(), x.max())
# Out:
# C:\Users\dvjp3\AppData\Local\Temp\ipykernel_12804\1282128664.py:10: RuntimeWarning: invalid value encountered in log
#   return np.log(x)
# (4.35, 8.85)

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
import pandas as pd
fitbit=pd.read_csv("Desktop\Fitbit2.csv")
fitbit.head(20)
# Out:
#           Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0   2015-05-08            1934    905      0.65       0              1.355
# 1   2015-05-09            3631  18925     14.11       4            611.000
# 2   2015-05-10            3204  14228     10.57       1            602.000
# 3   2015-05-11            2673   6756      5.02       8            749.000
# 4   2015-05-12            2495    502      3.73       1            876.000
# 5   2015-05-13             276    779      5.79      15            726.000
# 6   2015-05-14            2687   5614      4.17       2            782.000
# 7   2015-05-15            2793   8169      6.07      14            801.000
# 8   2015-05-16            4061  19971     14.84      18            532.000
# 9   2015-05-17            3349    852      6.33      12            606.000
# 10  2015-05-18            2961  11998      8.91      20            936.000
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
import math
# MEDIAN STEPS BY MONTH_ENCODED
# your code here
df2 = fitbit.groupby('Months_encoded')['Steps'].median()
print(df2)

df3 = fitbit.groupby('Work_or_Weekend')['Steps'].median()
print(df3)
# Out:
# Months_encoded
# 1    1970-01-01 00:00:00.000010366
# 2    1970-01-01 00:00:00.000009235
# 3    1970-01-01 00:00:00.000011122
# 4    1970-01-01 00:00:00.000013846
# 5    1970-01-01 00:00:00.000011998
# 6    1970-01-01 00:00:00.000012935
# 7    1970-01-01 00:00:00.000010644
# 8    1970-01-01 00:00:00.000012213
# 9    1970-01-01 00:00:00.000009343
# 10   1970-01-01 00:00:00.000007865
# 11   1970-01-01 00:00:00.000009453
# 12   1970-01-01 00:00:00.000008531
# Name: Steps, dtype: datetime64[ns]
# Work_or_Weekend
# 0   1970-01-01 00:00:00.000009998
# 1   1970-01-01 00:00:00.000010445
# Name: Steps, dtype: datetime64[ns]

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
fitbit['Minutes Lightly Active']
# Out:
# 0       46
# 1      316
# 2      226
# 3      190
# 4      171
#       ...
# 362    275
# 363    333
# 364    287
# 365    298
# 366    370
# Name: Minutes Lightly Active, Length: 367, dtype: int64

# %%
fig, ax=plt.subplots(figsize=(10,6))
ax.scatter(x=fitbit['Minutes Lightly Active'], y=fitbit['Steps'])
plt.xlabel("x")
plt.ylabel("y")

plt.show()

# %%
fig, ax=plt.subplots(figsize=(10,6))
ax.scatter(x=fitbit['Minutes Very Active'], y=fitbit['Steps'])
plt.xlabel("x")
plt.ylabel("y")

plt.show()

# %%
fig, ax=plt.subplots(figsize=(10,6))
ax.scatter(x=fitbit['Minutes Sedentary'], y=fitbit['Steps'])
plt.xlabel("x")
plt.ylabel("y")

plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your codimport pandas as pd
import pandas as pd
titanic=pd.read_csv("Desktop\titanic.csv")
titanic
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[57], line 3
#       1 # your codimport pandas as pd
#       2 import pandas as pd
# ----> 3 titanic=pd.read_csv("Desktop\titanic.csv")
#       4 titanic
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dytypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 titanic.dytypes
#
# NameError: name 'titanic' is not defined

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
numerics=['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
newtitanic=titanic.select_dtypes[include=numerics]

# %%
cattitanic=titanic.astype=["category"]

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code herfig, ax=plt.subplots(figsize=(10,6))
ax.scatter(x=titanic['Passengerid'], y=fitbit['Age'])
plt.xlabel("x")
plt.ylabel("y")

plt.show()

sns.lineplot(data.x, data.y)

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
plt.scatter(titanic['Age'])
 
# Adding Title to the Plot
plt.title("Scatter Plot")
 
# Setting the X and Y labels
plt.xlabel('Age')
plt.ylabel('Passengerid')
 
plt.colorbar()
 
plt.show()

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
plt.scatter(Age, bins=[10, 20, 50])

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here

The result has bins on nice intervals of bin size.
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
sns.displot(titanic, x="Age", binwidth=3)

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
plt.scatter(titanic['Gender'])
 
# Adding Title to the Plot
plt.title("Scatter Plot")
 
# Setting the X and Y labels
plt.xlabel('Gender')
plt.ylabel('Passengerid')
 
plt.colorbar()
 
plt.show()

# %%
# Method 2 - seaborn
# your code here
df = sns.load_dataset("titanic")
sns.barplot(data=df, x="Gender", y="Passengerid")

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
bp = titanic.boxplot(column='age', by='pclass', grid=False)
for i in [1,2,3]:
    y = titanic.age[titanic.pclass==i].dropna()
    # Add some random "jitter" to the x-axis
    x = np.random.normal(i, 0.04, size=len(y))
    plot(x, y, 'r.', alpha=0.2)

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
titanic = pd.DataFrame(np.random.normal(size=(2000,)))
fig, ax = plt.subplots()
ax.hist(df[0])
plt.figtext(0.1,0.5, df.describe().to_string())
plt.figtext(0.75,0.5, df.describe().loc[['mean','std']].to_string())

# %%
"""
your comments here
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
np.corrcoef(titanic['Fare'], titanic['Age'])

# %%
# Method 2 - seaborn
# your code here

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code h

dataplot=sb.heatmap(titanic.corr())
  
# displaying heatmap
mp.show()

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
def describe_helper(series):
    splits = str(series.describe()).split()
    keys, values = "", ""
    for i in range(0, len(splits), 2):
        keys += "{:8}\n".format(splits[i])
        values += "{:>8}\n".format(splits[i+1])
    return keys, values

demo = np.random.uniform(0,10,100)
plt.hist(demo, bins=10)
plt.figtext(.95, .49, describe_helper(pd.Series(demo))[0], {'multialignment':'left'})
plt.figtext(1.05, .49, describe_helper(pd.Series(demo))[1], {'multialignment':'right'})
plt.show()

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
sns.set_style("whitegrid")
sns.displot(titanic, x="Age", hue="species", multiple="Gender")
