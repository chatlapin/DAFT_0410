# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('Desktop/liquor_store_sales.csv')
data.head()

# %%
#1
data.dtypes

import plotly.graph_objects as go

fig=go.Figure(go.Bar(
x=data["ItemType"], 
y=['RetailSales', 'RetailTransfers', 'WarehouseSales'], orientation='h'))

fig.show()

# %%
#2

data.sort_values('Supplier',ascending=False,inplace=True)
(data.head(10))

# %%
import plotly.express as px
data = pd.read_csv('Desktop/liquor_store_sales.csv')
fig=px.bar(data, x='Supplier', y='RetailSales', color='Month', orientation='h', hover_data=["RetailTransfers", "WarehouseSales"], height=400, title="supplier top 10")
fig.show()

# %%
#3

import matplotlib.pyplot as plt

plt.plot(df['Retail Sales'])
plt.plot(df['Retail Transfers'])
plt.plot(df['Warehouse Sales'])

plt.show()

# %%
#4

data.plot(x='ItemType, y=[Retail Sales','Retail Transfers','Warehouse Sales'], kind='bar')

# %%
#5

sns.displot(data, x='Retail Sales', binwidth=3)

# %%
#6

df.sns.load_dataset("data")
sns.barplot(data=df, x="Retail Sales", y="ItemType")

# %%
#7

fig, ax=plt.subplots(figsize=(10,6))
ax.scatter(x=data["Retail Sales"], y=data[RetailTransfers])
plt.xlabel['x']
plt.ylable["y"]

plt.show()

# %%
#8

plt.scatter(data["Retail Sales"])

plt.title("Scatter Plot")

plt.xlabel("Retail Sales")
plt.ylable('ItemType')

plt.colorbar()

plt.show()
