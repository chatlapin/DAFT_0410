# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Desktop\Pokemon.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
result=df.head(11)
print(result)
# Out:
#     #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0   1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1   2                    Ivysaur  Grass  Poison    405  60      62       63
# 2   3                   Venusaur  Grass  Poison    525  80      82       83
# 3   3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4   4                 Charmander   Fire     NaN    309  39      52       43
# 5   5                 Charmeleon   Fire     NaN    405  58      64       58
# 6   6                  Charizard   Fire  Flying    534  78      84       78
# 7   6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8   6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9   7                   Squirtle  Water     NaN    314  44      48       65
# 10  8                  Wartortle  Water     NaN    405  59      63       80
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df["Type 1"]
# Out:
# 0        Grass
# 1        Grass
# 2        Grass
# 3        Grass
# 4         Fire
#         ...
# 795       Rock
# 796       Rock
# 797    Psychic
# 798    Psychic
# 799       Fire
# Name: Type 1, Length: 800, dtype: object

# %%
df["Type 2"]
# Out:
# 0      Poison
# 1      Poison
# 2      Poison
# 3      Poison
# 4         NaN
#         ...
# 795     Fairy
# 796     Fairy
# 797     Ghost
# 798      Dark
# 799     Water
# Name: Type 2, Length: 800, dtype: object

# %%
Type1=df['Type 1'].unique()
Type2=df['Type 2'].unique()

unique_types=pd.concat([df['Type 1'], df['Type 2']]).unique()
print(unique_types)
# Out:
# ['Grass' 'Fire' 'Water' 'Bug' 'Normal' 'Poison' 'Electric' 'Ground'
#  'Fairy' 'Fighting' 'Psychic' 'Rock' 'Ghost' 'Ice' 'Dragon' 'Dark' 'Steel'
#  'Flying' nan]

# %%
type(unique_types)
# Out:
# numpy.ndarray

# %%
df.loc[df['Name'].str.contains("Mega"),'Name'] = 'Mega' + df['Name'][df['Name'].str.contains("Mega")].str.split
#df['Name'].apply(lambda x: x.replace('*Mega*', ''))
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[202], line 1
# ----> 1 df.loc[df['Name'].str.contains("Mega"),'Name'] = 'Mega' + df['Name'][df['Name'].str.contains("Mega")].str.split
#       2 #df['Name'].apply(lambda x: x.replace('*Mega*', ''))
#       3 df.head(10)
#
# TypeError: can only concatenate str (not "method") to str

# %%
df['A/D Ratio'] = df['Attack']/df['Defense']
df['A/D Ratio']
# Out:
# 0      1.000000
# 1      0.984127
# 2      0.987952
# 3      0.813008
# 4      1.209302
#          ...
# 795    0.666667
# 796    1.454545
# 797    1.833333
# 798    2.666667
# 799    0.916667
# Name: A/D Ratio, Length: 800, dtype: float64

# %%
max_Pokemon=df['A/D Ratio'].max()
df[df['A/D Ratio']==max_Pokemon]
# Out:
#        #                Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic    NaN    600  50     180       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio Combo-Type  \
# 429      180       20    150           3       True        9.0        NaN
#
#     ComboType  A/D Ratio_Max5
# 429       NaN             1.8

# %%
min_Pokemon=df['A/D Ratio'].min()
df[df['A/D Ratio']==min_Pokemon]
# Out:
#        #     Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 230  213  Shuckle    Bug   Rock    505  20      10      230       10      230
#
#      Speed  Generation  Legendary  A/D Ratio Combo-Type ComboType  \
# 230      5           2      False   0.043478    BugRock  Bug-Rock
#
#      A/D Ratio_Max5
# 230        0.043478

# %%
df.loc[df['Type 2'].isnull()==False, 'Combo Type']=df[['Type 1', 'Type 2']].astype(str).apply('-'.join, axis=1)
df.loc[df['Type 2'].isnull()==True, 'Combo Type']=df['Type 1']

# %%
#df['A/D Ratio'].sort_values()
#df.sort_values(by=['A/D Ratio', 'Name'])
#top5=df.nlargest(5, 'A/D Ratio', keep='last')
top_5=df.sort_values('A/D Ratio', ascending=False)[:5]
top_5
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 429  386     DeoxysAttack Forme  Psychic     NaN    600  50     180       20
# 347  318               Carvanha    Water    Dark    305  45      90       20
# 19    15  BeedrillMega Beedrill      Bug  Poison    495  65     150       40
# 453  408               Cranidos     Rock     NaN    350  67     125       40
# 348  319               Sharpedo    Water    Dark    460  70     120       40
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio Combo-Type  \
# 429      180       20    150           3       True      9.000        NaN
# 347       65       20     65           3      False      4.500  WaterDark
# 19        15       80    145           1      False      3.750  BugPoison
# 453       30       30     58           4      False      3.125        NaN
# 348       95       40     95           3      False      3.000  WaterDark
#
#       ComboType  A/D Ratio_Max5  Combo Type
# ...

# %%
#df.nsmallest(5, 'A/D Ratio', keep='last')

# %%
#top5_combo = sorted(df.loc['A/D Ratio','ComboType'].unique())
top5_combo = sorted([top_5['Combo Type'].unique()])
top5_combo
# Out:
# [array(['Psychic', 'Water-Dark', 'Bug-Poison', 'Rock'], dtype=object)]
